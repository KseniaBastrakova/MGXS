# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import h5py
import copy
from scipy.optimize import curve_fit

# %%
class Sig:
    def __init__(self):
        self.number_groups = 0
        self.sig_f = []
        self.capture = []
        self.scattering = []
        self.total = []
        self.number_of_production_neutrons = []
        self.c_value = []
        self.virtual = []
        
    def __init__(self, number_groups, sig_f, sig_c, sig_scattering_matrix, number_of_production_neutrons,
                 cs_xi_table, sig_t, anisotropic = []):
        self.number_groups = number_groups
        self.sig_f = sig_f
        self.sig_c = sig_c
        self.sig_s = []
        self.sig_scattering_matrix = sig_scattering_matrix

        for i in range(0, len(self.sig_scattering_matrix)):
            self.sig_s.append(sum(self.sig_scattering_matrix[i]))
            
        self.number_of_production_neutrons = number_of_production_neutrons
        self.cs_xi_table = cs_xi_table
        self.sig_t = sig_t
        self.delta_xs = max(sig_t)/2.
        max_total_cs = max(self.sig_t)
        self.virtual = [self.delta_xs]
        self.anisotropic = anisotropic
        
               
    def get_virtual_cs(self):
        max_total_cs = max(self.sig_t)
        self.virtual = [cross_section - max_total_cs + self.delta_xs for cross_section in self.sig_t]
        
    def return_virtual(self):
        return self.virtual
        
    def get_fission_probability(self, energy_group_idx):
        return self.sig_f[energy_group_idx] / self.sig_t[energy_group_idx]
    
    def get_capture_probability(self, energy_group_idx):
        return self.sig_c[energy_group_idx] / self.sig_t[energy_group_idx]
        
    def get_scatter_probability(self, energy_group_idx):
        return self.sig_s[energy_group_idx] / self.sig_t[energy_group_idx]
    
    def get_anisotropic(self, energy_group_idx, energy_sub_group):
        return self.anisotropic[energy_group_idx][energy_sub_group]

# %%
energy_groups_2 = [0, 6.25, 2 * 1E10]

class Positon:
    def __init__(self, x, y, z):
        self.x = x
        self.y = y
        self.z = z
        
class Direction:
    def __init__(self, ets, phi):
        self.tetta_x = math.sin(ets) * math.cos(phi)
        self.tetta_y = math.sin(ets) * math.sin(phi)
        self.tetta_z = math.cos(ets)

# %%
class Particle:
    def __init__(self):
        self.coordinates = Positon(0, 0, 0)
        self.direction = Direction(0, 0)
        self.energy = 0.
        self.weight = 1
        self.energy_groups = []
        self.terminated = False
        self.path = 0.
        self.last_cell = 0
        self.energy_group = 0
        
    def set_coordinates(self, x, y, z):
        self.coordinates = Positon(x, y, z)
        
    def set_direction(self, ets, phi):
        self.direction = Direction(ets, phi)
    
    def set_direction_angle(self, angle):
        self.direction = angle
        
    def set_energy_groups(self, energy_groups):
        self.energy_groups = energy_groups
        
    def get_energy_group(self): 
        
        return self.energy_group
     #   res = next(x for x, val in enumerate(self.energy_groups)
      #                            if val > self.energy)        
       # return res - 1
    
    def set_energy_group(self, energy_group):
        
        self.energy_group = energy_group       
    
    def set_terminated(self):
        self.terminated = True
        
    def is_terminated(self):
        return self.terminated
        
    def get_weight(self):
        return self.weight
    
    def set_weight(self, weight):
        self.weight = weight
    
    def set_particle_deleted(self):
        self.weight = self.weight * 0
        
    def set_particle_fission(self, additional_weight):
        self.weight = self.weight * additional_weight
        
    def set_multiplicity(self, additional_weight):
        self.weight = self.weight * additional_weight
              
    def is_particle_deleted(self):
        return self.weight < 0.0001
    
    def add_path(self, path):
        self.path += path
    
    def get_path(self):
        return self.path
    
    def set_path(self, path):
        self.path = path
        
    def print_direction(self):
        print(str(self.direction.tetta_x) + " " + str(self.direction.tetta_y) + " " + str(self.direction.tetta_z))
        
    def print_coordinates(self):
        print(str(self.coordinates.x) + "  " + str(self.coordinates.y) + " " + str(self.coordinates.z))

# %%
class Plane:
    def __init__(self, A, B, C, D):
        self.A = A
        self.B = B
        self.C = C
        self.D = D
        
    def distance(self, particle):
        vp = (self.A * particle.direction.tetta_x + self.B * particle.direction.tetta_y + 
              self.C * particle.direction.tetta_z)
        
        
        if (abs(vp) < 1e-9):
            return -1
        
        distance = (self.D - self.A * particle.coordinates.x - self.B * particle.coordinates.y 
                    - self.C * particle.coordinates.z) / vp
        
        return distance 
    
    def get_normal(self):
        sq = math.sqrt(self.A * self.A + self.B * self.B + self.C * self.C)
        a_n = self.A / sq
        b_n = self.B / sq
        c_n = self.C / sq
        return [a_n, b_n, c_n]
    

    def get_sign(self, particle):
      
        sign = (self.A * particle.coordinates.x + self.B * particle.coordinates.y +
        self.C * particle.coordinates.z - self.D)
        
        if sign == 0:
            return sign    
            
        if sign < 0:
            return -1
        else:
            return 1
        
    def get_xml(self):
        
        obj_xml = " Plane with A "+ str(self.A) + " B "+ str(self.B) + " C "+ str(self.C) + " D "+ str(self.D)
        
        return obj_xml

# %%
class Universe:
    def __init__(self, cells, xs):
        self.cells = cells
        self.xs = xs
        self.delta_xs = 0.
        
    def calculate_delta_xs(self):
        
        delta_xs = []
        for i in range(0, self.xs[0].number_groups):
            energy_group_maximum = -1
            for xs in self.xs:
                energy_group_maximum = max(energy_group_maximum, xs.sig_t[i])
            delta_xs.append(energy_group_maximum)
            
        self.delta_xs = delta_xs                          
            
    def get_delta_xs(self, energy_group):
        
        return self.delta_xs[energy_group]
    
    def get_xs_by_coordinates(self, particle):
        
        for i in range(0, len(cells)):
            cell = cells[i]
            if cell.is_inside(particle):
                particle.last_cell = i
                return self.xs[i]
        return []
    
    def is_inside(self, particle):
        
        for cell in self.cells:
            if cell.is_inside(particle):
                return True
        return False
        
    
    def is_boudary_reflective(self, particle):
        
        minumum = np.inf
        idx_of_min = 0.
        for i in range(0, len(self.cells)):
            distance, surface_idx = self.cells[i].get_minimum_distance(particle)
            if abs(distance) < minumum:
                minumum = distance
                idx_of_min = i
        if self.cells[idx_of_min].is_boudary_reflective(particle):
            return True
        else:
            return False
        
    def reflect_particle(self,  particle):
        self.cells[particle.last_cell].reflect_particle(particle)

# %%
def set_random_direction(particle):
    r = 1.0
    r1 = 1.0
    while (r**2 + r1**2 > 1.0):
        r = 2. * random.uniform(0, 1) - 1.
        r1 = 2. * random.uniform(0, 1) - 1.
        
    direction_x = 2.0 * r**2 + 2. * r1**2 - 1.0  
    particle.direction.tetta_x = direction_x
    particle.direction.tetta_y = r * math.sqrt((1.0 - direction_x**2)/(r**2+r1**2))
    particle.direction.tetta_z = r1 * math.sqrt((1.0 - direction_x**2)/(r**2+r1**2))

# %%
class Flux_estimator:
    def __init__(self, universe, group):
        self.boundaries = universe
        self.collision_sum = [0]
        self.group = group
        
    def add_collision(self, particle):
        if (self.boundaries.is_inside(particle) and particle.get_energy_group() == self.group):
            self.collision_sum[-1]  += particle.get_weight()

# %%
import random

def make_initial_sources(number_of_paricles, box_size, zero_point, energy=10.0e6):
    
    step_x = box_size[0]/number_of_paricles
    step_y = box_size[1]/number_of_paricles
    step_z = box_size[2]/number_of_paricles
    
    x_coord = zero_point[0]
    y_coord = zero_point[1]
    z_coord = zero_point[2]
    
    sources = []
    for i in range(0, number_of_paricles):
        for j in range(0, number_of_paricles):
            for k in range(0, number_of_paricles):
                current_particle = Particle()
                current_particle.set_coordinates(x_coord + k * step_x, y_coord + j * step_y, z_coord+ i * step_z)
                set_random_direction(current_particle)
                energy_group = random.choice([0, 1])
                current_particle.set_energy_group(energy_group)
                current_particle.energy = energy
                current_particle.set_energy_groups(energy_groups_2)
                sources.append(current_particle)

    return sources

# %%
def get_free_path(particle, delta_xs):
    
    energy_group_idx = particle.get_energy_group()
    sig_t = delta_xs
    free_path = -math.log(random.uniform(0, 1)) / sig_t
    
    return free_path

# %%
class Cell:
    def __init__(self):
        self.surfaces = []
        self.boundaries_type = []
        self.signs = []
        self.size = 0
        
    def set_boundaries_type(self, boundaries_type):
        self.boundaries_type = boundaries_type        
        
    def set_box_sizes(self, xm_size, ym_size, zm_size, x_size, y_size, z_size):
        self.xm_size = xm_size
        self.ym_size = ym_size
        self.zm_size = zm_size
        
        self.x_size = x_size
        self.y_size = y_size
        self.z_size = z_size
        
    def set_zero_point(self, x_0, y_0, z_0):
        self.x_0 = x_0
        self.y_0 = y_0
        self.z_0 = z_0
        
    def __init__(self, surfaces, signs):
        self.surfaces = surfaces
        self.signs = signs
        self.size = len(self.signs)
           
    def is_inside(self, particle):
        
        is_inside = True
        for i in range(0, self.size):
            sign = self.surfaces[i].get_sign(particle)
            if self.signs[i] != sign:
                is_inside = False
                
        return is_inside
    
    def is_boudary_reflective(self, particle):
        for i in range(0, self.size):
            sign = self.surfaces[i].get_sign(particle)
            if self.signs[i] != sign:
                if self.boundaries_type[i] == 'reflective':
                    return True
                else:
                    return False
        
    
    def get_minimum_distance(self, particle):
        
        minimum_distance = math.inf
        surface_idx = 0
        for i in range(0, len(self.surfaces)):
            current_distance = abs(self.surfaces[i].distance(particle))
            if current_distance > 0:
                minimum_distance = min(minimum_distance, current_distance)
                surface_idx = i
        return minimum_distance, surface_idx
    
    def get_xml(self):
        
        xml_obj = []
        for i in range(0, self.size):
            xml_obj.append(surfaces[i].get_xml())
            
        return xml_obj
    
    def reflect_particle(self, particle):
        
        if particle.coordinates.x > (self.x_size + self.x_0):
            delta = particle.coordinates.x % self.x_size
            particle.coordinates.x = self.xm_size + math.fabs(delta)
        
        if particle.coordinates.y > (self.y_size + self.y_0):
            
            delta = particle.coordinates.y % self.y_size
            particle.coordinates.y = self.ym_size + math.fabs(delta)
            
            
        if particle.coordinates.z > (self.z_size + self.z_0):
            
            delta = particle.coordinates.z % self.z_size
            particle.coordinates.z = self.zm_size + math.fabs(delta)
        
        
        if particle.coordinates.y < (self.ym_size + self.y_0):
            delta = particle.coordinates.y % self.ym_size
            particle.coordinates.y = self.y_size - math.fabs(delta)
            
            
        if particle.coordinates.x < (self.xm_size + self.x_0):
            delta = particle.coordinates.x % self.xm_size
            particle.coordinates.x = self.x_size - math.fabs(delta)
            
        if particle.coordinates.z < (self.zm_size + self.z_0):
            delta = particle.coordinates.z % self.zm_size
            particle.coordinates.z = self.z_size - math.fabs(delta)

# %%
def move_particle(particle, t):
    new_x = particle.direction.tetta_x * t + particle.coordinates.x
    new_y = particle.direction.tetta_y * t + particle.coordinates.y
    new_z = particle.direction.tetta_z * t + particle.coordinates.z
    particle.set_coordinates(new_x, new_y, new_z)

# %%
def is_collision_virual(particle, c_s, delta_xs):
    
    energy_group_idx = particle.get_energy_group()
    random_number = random.uniform(0, 1)
    
    virtual_cs = delta_xs
    
    total_cs = c_s.sig_t[energy_group_idx]
    
    if total_cs / virtual_cs < random_number:
        return True
    else:
        return False

# %%
def process_virtual_collision(particle, free_path):
    particle.add_path(free_path)

# %%
def calculate_mu(anisotropic_coeffs):
    
    
    b = 3. * anisotropic_coeffs[1] / anisotropic_coeffs[0]
    gamma =  random.uniform(0, 1)
    sqr = (1/2 - b)**2 + 2 * b * gamma
    

    result_mu1 = (-1/2 + math.sqrt(sqr))/b
    result_mu2 = (-1/2 - math.sqrt(sqr))/b
  #  if abs(result_mu1) < 1:
   #     return result_mu1
    
   # if abs(result_mu2) < 1:
    #    return result_mu2
    
    
    return anisotropic_coeffs[1]/ anisotropic_coeffs[0]

# %%
def calculate_mu_qvadric(anisotropic_coeffs):
    
    b = 3. * anisotropic_coeffs[1] / anisotropic_coeffs[0]
    gamma =  random.uniform(0, 1)
    sqr = (1/2 - b)**2 + 2 * b * gamma
    

    result_mu1 = (-1/2 + math.sqrt(sqr))/b
    result_mu2 = (-1/2 - math.sqrt(sqr))/b
    if abs(result_mu1) < 1:
        return result_mu1
    
    if abs(result_mu2) < 1:
        return result_mu2

# %%
def get_anisotropic_direction_2(particle, mu):
    
    
    dir_x = particle.direction.tetta_x
    dir_y = particle.direction.tetta_y
    dir_z = particle.direction.tetta_z
    
    b = math.sqrt(1 - mu * mu)
    ro = math.sqrt(1 - dir_z * dir_z)
    phi = random.uniform(-math.pi, math.pi)

    c = math.cos(phi)
    d = math.sin(phi)
    a = mu
    
    dir_x_tmp = (b * c * dir_x * dir_z)/ro  - (b * d * dir_y)/ro + a * dir_x    
    dir_y_tmp = (b * c * dir_y * dir_z)/ro  + (b * d * dir_x)/ro + a * dir_y  
    dir_z_tmp = -b * c * ro  + a * dir_z
    
    particle.direction.tetta_x = dir_x_tmp
    particle.direction.tetta_y = dir_y_tmp
    particle.direction.tetta_z = dir_z_tmp

# %%
def process_scattering(particle, c_s):
    
    energy_group_idx = particle.get_energy_group()   
    
    energy_group_probability = []
    energy_scattering_matrix = c_s.sig_scattering_matrix[energy_group_idx]
    
    majorant = sum(energy_scattering_matrix)
    for i in range(0, len(energy_scattering_matrix)):
        energy_group_probability.append(energy_scattering_matrix[i] / majorant)
        
    energy_groups_idxes = list(range(0, len(energy_scattering_matrix)))
    energy_group_idx_new = np.random.choice(energy_groups_idxes,  p=energy_group_probability)
    
    particle.set_energy_group(energy_group_idx_new)
    anisotropic_coeffs = c_s.get_anisotropic(energy_group_idx, energy_group_idx_new)
    mu = calculate_mu(anisotropic_coeffs)
  #  set_random_direction(particle)
    get_anisotropic_direction_2(particle, mu)

# %%
def process_fission(particle, c_s):
    energy_group_idx = particle.get_energy_group()
    number_of_production_neutrons = c_s.number_of_production_neutrons[energy_group_idx]
    particle.set_particle_fission(number_of_production_neutrons)
    particle.set_terminated()
    energy_groups_idxes = list(range(0, c_s.number_groups))
    xi_matrix = c_s.cs_xi_table
    energy_group_idx = np.random.choice(energy_groups_idxes,  p=xi_matrix)
    particle.set_energy_group(energy_group_idx)
    set_random_direction(particle)

# %%
def process_real_collision(particle, free_path, c_s):
    
    energy_group_idx = particle.get_energy_group()
    number_of_production_neutrons = c_s.number_of_production_neutrons[energy_group_idx]   
    capture_probability = c_s.get_capture_probability(energy_group_idx)
    scatter_probability = c_s.get_scatter_probability(energy_group_idx)  
    fission_probability = c_s.get_fission_probability(energy_group_idx)  
    
    type_collision = np.random.choice(['capture', 'scatter', 'fission'], p=[capture_probability, scatter_probability,
                                                                            fission_probability])
    if type_collision == 'capture':
        particle.set_terminated()
        particle.set_weight(0.)
        
    if type_collision == 'scatter':      
        process_scattering(particle, c_s)
        
    if type_collision == 'fission':    
        process_fission(particle, c_s)

# %%
def delete_absorpbed_paricles(particles):
    
    existing_particles = []
    for i in range(0, len(particles)):
        particle = particles[i]
        if particle.get_weight() > 0.000001:
            existing_particles.append(particle)
                     
    return existing_particles

# %%
def process_one_particle_history(particle, universe, estimators):
    
    sum_collisions = 0.
    universe.calculate_delta_xs()
    
    
    while not particle.is_terminated():
     #   set_random_direction(particle)
        current_xs = universe.get_xs_by_coordinates(particle)
        energy_group_idx = particle.get_energy_group()
        delta_xs = universe.get_delta_xs(energy_group_idx)
        free_path = get_free_path(particle, delta_xs)        
        move_particle(particle, free_path)
        current_xs = universe.get_xs_by_coordinates(particle)
        
        if not universe.is_inside(particle):
            if universe.is_boudary_reflective(particle):
                universe.reflect_particle(particle)
                current_xs = universe.get_xs_by_coordinates(particle)

            else:
                particle.set_terminated()
                particle.set_weight(0.)
                return particle, sum_collisions
                
        for k in estimators:
            k.add_collision(particle)
        
        if is_collision_virual(particle, current_xs, delta_xs):
            process_virtual_collision(particle, free_path)
        else:
            process_real_collision(particle, free_path, current_xs)
        
            
    return particle, sum_collisions

# %%
def get_weights(particles):
    
    weights = []
    for i in range(0, len(particles)):
        weights.append(particles[i].weight)
        
    return weights

# %%
def make_sources(particles):
    for i in range(0, len(particles)):
        particles[i].terminated = False
     #   set_random_direction(particles[i])

# %%
def splitting_secound_version(particles):
    
    initial_size = len(particles)
    
    for i in range(0, initial_size):
        particle = particles[i]
        current_weight = particle.get_weight()
        if current_weight > 1:
            n_value = math.floor(current_weight)
            random_value = random.uniform(0, 1)
            if current_weight - n_value >= random_value:
                n_value += 1
            if n_value > 1:
                particle.set_weight(current_weight / n_value)
                for j in range(0, n_value - 1):
                    particles.append(copy.deepcopy(particle))

# %%
def normalise_weights(particles, batch_size):

    sum_weights = 0.
    
    for i in range(0, len(particles)):
        sum_weights += particles[i].get_weight()

    for i in range(0, len(particles)):
        particles[i].weight = (particles[i].weight * batch_size) / sum_weights   
        
    return particles

# %%
def russian_roulette(weights_previous, particles_current):
    
    for i in range(0, len(particles_current)):
        particle = particles_current[i]
        if particle.weight > 0 and particle.weight < 0.5 and particle.weight < weights_previous[i]:
            probability_terminate = 1. - particle.weight / weights_previous[i]
            random_number = random.uniform(0, 1)
            if probability_terminate >= random_number:
                particle.set_weight(0.)
            else:
                particle.set_weight(weights_previous[i])

# %%
def terminate_outside_particles(batch_particles, universe):
    
    for j in range(0, len(batch_particles)):
        particle = batch_particles[j]
        if not universe.is_inside(particle):
            print("ERROR! outside particle")

# %%
def reset_estimators(estimators, weight_previos, volume, sum_collisions, c_s):
    
    sig_t = c_s.sig_t[0]

    for estimator in estimators:
        estimator.collision_sum[-1] = estimator.collision_sum[-1]
        estimator.collision_sum.append(0.)

# %%
def get_std(values):
    
    current_std = np.std(values)/np.sqrt((len(values) - 1.))
  
    return current_std

# %%
def calculate_k_effective(idx, weights, number_interations, number_inactive, initial_size, k_effective,
                         k_effective_exp, std_k_effective):
    
    keff_cycle = sum(weights) / initial_size
    if idx > number_inactive:
        k_effective.append(keff_cycle)
        
    if idx > number_inactive + 1:
    
        k_effective_exp.append(sum(k_effective) / len(k_effective))
        
        std_k_effective_current = get_std(k_effective)
            
        std_k_effective.append(std_k_effective_current)

        print(" keff_cycle , k_effective_exp, std_k_effective " + str(keff_cycle) + "   " + str(k_effective_exp[-1]) +
                                    "  "+ str(std_k_effective[-1]))

# %%
import statistics
import time


def simulation_black_boundaries(universe, number_interations, number_inactive, number_of_particles, c_s, estimators,
                                volume=1):
    
    random.seed(time.time())
    k_effective = []
    k_effective_std = []
    k_effective_exp = []
    flux = []
    flux_exp = []
    num1 = random.randint(0,9)
    
    print(" num1  " + str(num1))
    
    box_size = [1., 1., 1.]
    zero_point = [0.1, 0.1, 0.1]
    initial_sources = make_initial_sources(number_of_particles, box_size, zero_point, energy=10.0e6)
    initial_size = len(initial_sources)
    
    weights_previous = [1.] * len(initial_sources)
    
    for i in range(0, number_interations):
        print("i == " + str(i))
        
        make_sources(initial_sources)
        batch_size = len(initial_sources)
        
        batch_particles = []

        for j in range(0, batch_size):
   
            particle = initial_sources[j]
            terminate_particle, sum_collisions = process_one_particle_history(particle, universe, estimators)
            batch_particles.append(terminate_particle)
        
        russian_roulette(weights_previous, batch_particles)
        
        batch_particles = delete_absorpbed_paricles(batch_particles)
        
        splitting_secound_version(batch_particles)
        
        weights_cycle = get_weights(batch_particles)
        
        calculate_k_effective(i, weights_cycle, number_interations, number_inactive, initial_size, k_effective,
                         k_effective_exp, k_effective_std)
        
        
        reset_estimators(estimators, weights_previous, volume, sum_collisions, c_s) 
      

        batch_particles = normalise_weights(batch_particles, initial_size)  

        initial_sources = batch_particles
        weights_previous = get_weights(batch_particles)

            
    return k_effective, k_effective_exp, k_effective_std, estimators

# %%
cs_fission_rr = [0.050632, 0.0010484]

cs_capture_rr = [0.025788, 0.0010046]

cs_scattering_rr = [[2.44383, 0.0], [0.029227, 0.62568]]

cs_total_rr = [2.52025, 0.65696]

cs_production_neutrons_rr = [2.50, 2.50]

cs_xi_table_rr = [ 0., 1.]
cs_anisotropic =[[[2.44383, 0.83318], [0., 0,]], [[0.029227, 0.0075737], [0.62568, 0.27459]]]


research_reactor_b = Sig(2, cs_fission_rr, cs_capture_rr, cs_scattering_rr, 
                       cs_production_neutrons_rr,  cs_xi_table_rr, cs_total_rr, cs_anisotropic)


energy_groups_2 = [0, 2 * 1E10]

# %%
x_5 = Plane(1, 0, 0, 1000)
x_m5 = Plane(1, 0, 0, -1000)

y_5 = Plane(0, 1, 0, 9.4959)

y_m5 = Plane(0, 1, 0, -9.4959)


z_5 = Plane(0, 0, 1, 1000)
z_m5 = Plane(0, 0, 1, -1000)

surfaces = [x_5, x_m5, y_5, y_m5, z_5, z_m5]

signs = [-1, +1, -1, +1, -1, +1]
slab = Cell(surfaces, signs)

boundaries_type = ["reflective", "reflective", "black", "black", "reflective", "reflective"]


slab.set_boundaries_type(boundaries_type)
slab.set_box_sizes(-1000, -9.4959, -1000, 1000, 9.4959, 1000 )
slab.set_zero_point(0., 0., 0.)

# %%
estimators = []

# %%
cells = [slab]

# %%
materials = [research_reactor_b]

# %%
U235_Reactor = Universe(cells, materials)

# %%
test_number_of_particles = 10
test_number_interations = 1000
test_number_inactive = 10

# %%
k_effective, k_effective_exp, k_effective_std, estimators_result = simulation_black_boundaries(U235_Reactor,  
                           test_number_interations,  test_number_inactive, 
                          test_number_of_particles, research_reactor_b, estimators)
# Out:
#  num1  9
# i == 0
# i == 1
# i == 2
# i == 3
# i == 4
# i == 5
# i == 6
# i == 7
# i == 8
# i == 9
# i == 10
# i == 11
# i == 12
#  keff_cycle , k_effective_exp, std_k_effective 0.975436232517671   1.0081202577904773  0.03268402527280628
# i == 13
#  keff_cycle , k_effective_exp, std_k_effective 1.0116185166758414   1.0092863440855986  0.018906125813048437
# i == 14
#  keff_cycle , k_effective_exp, std_k_effective 1.0172280588682352   1.0112717727812577  0.01351527741982957
# i == 15
#  keff_cycle , k_effective_exp, std_k_effective 1.0080980815863563   1.0106370345422775  0.010488113599356025
# i == 16
#  keff_cycle , k_effective_exp, std_k_effective 0.9527971387654748   1.0009970519128104  0.012894299115439566
# i == 17
#  keff_cycle , k_effective_exp, std_k_effective 1.0194361556782414   1.0036312095935862  0.011211513566753354
# i == 18
#  keff_cycle , k_effective_exp, std_k_effective 1.0597807941804278   1.0106499076669415  0.011980636460056737
# i == 19
#  keff_cycle , k_effective_exp, std_k_effective 1.0081906237448657   1.010376653897822  0.010569461031761523
# i == 20
#  keff_cycle , k_effective_exp, std_k_effective 1.0465349446980265   1.0139924829778424  0.010121512986577744
# i == 21
#  keff_cycle , k_effective_exp, std_k_effective 0.9263771653802862   1.0060274541053373  0.012135087221379603
# i == 22
#  keff_cycle , k_effective_exp, std_k_effective 1.031631525860428   1.0081611267515949  0.011281378928133292
# i == 23
#  keff_cycle , k_effective_exp, std_k_effective 1.005196509177794   1.007933079245918  0.010379864714415635
# i == 24
#  keff_cycle , k_effective_exp, std_k_effective 1.0387031095468218   1.0101309385531254  0.009858018112012553
# i == 25
#  keff_cycle , k_effective_exp, std_k_effective 0.982557427040886   1.0082927044523093  0.009359605915489594
# i == 26
#  keff_cycle , k_effective_exp, std_k_effective 0.9708015340970956   1.0059495063051085  0.009063251215135487
# i == 27
#  keff_cycle , k_effective_exp, std_k_effective 1.0242420437036825   1.0070255379167894  0.008581173604530487
# i == 28
#  keff_cycle , k_effective_exp, std_k_effective 0.9885398585721474   1.0059985557309759  0.008155329240158986
# i == 29
#  keff_cycle , k_effective_exp, std_k_effective 1.0340155094683698   1.0074731322434702  0.007853838676571077
# i == 30
#  keff_cycle , k_effective_exp, std_k_effective 1.0448382508263139   1.0093413881726123  0.007681463661218364
# i == 31
#  keff_cycle , k_effective_exp, std_k_effective 1.006285067169351   1.0091958490772188  0.007307978711452147
# i == 32
#  keff_cycle , k_effective_exp, std_k_effective 0.9772548324910205   1.0077439846869372  0.007117536223082637
# i == 33
#  keff_cycle , k_effective_exp, std_k_effective 0.9559310046928333   1.005491246426324  0.0071644255270591544
# i == 34
#  keff_cycle , k_effective_exp, std_k_effective 0.8989778981036999   1.0010531902462145  0.008169940005666228
# i == 35
#  keff_cycle , k_effective_exp, std_k_effective 1.0144952744245632   1.0015908736133485  0.007854755853862241
# i == 36
#  keff_cycle , k_effective_exp, std_k_effective 0.9090712501204599   0.9980324265559297  0.00834348831895629
# i == 37
#  keff_cycle , k_effective_exp, std_k_effective 1.0450668876449787   0.9997744436333019  0.008215341943371743
# i == 38
#  keff_cycle , k_effective_exp, std_k_effective 0.9650418178317551   0.998533992711818  0.008013096516887391
# i == 39
#  keff_cycle , k_effective_exp, std_k_effective 1.0038236180535383   0.9987163935856704  0.007733998293665954
# i == 40
#  keff_cycle , k_effective_exp, std_k_effective 1.024085879967313   0.9995620431317251  0.007519455041473547
# i == 41
#  keff_cycle , k_effective_exp, std_k_effective 1.0482659526982452   1.0011331369887098  0.007440608569960817
# i == 42
#  keff_cycle , k_effective_exp, std_k_effective 0.971788369316075   1.0002161129989398  0.0072624667225383455
# i == 43
#  keff_cycle , k_effective_exp, std_k_effective 0.9797920151545731   0.9995972009430498  0.007066109533845201
# i == 44
#  keff_cycle , k_effective_exp, std_k_effective 0.9265247063457427   0.9974480099254821  0.00718414036618846
# i == 45
#  keff_cycle , k_effective_exp, std_k_effective 0.9762339185798841   0.9968418930298936  0.007002142573374798
# i == 46
#  keff_cycle , k_effective_exp, std_k_effective 0.9563443206813087   0.9957169604646552  0.006897215740498986
# i == 47
#  keff_cycle , k_effective_exp, std_k_effective 1.0185594269053782   0.9963343244225126  0.00673656338216969
# i == 48
#  keff_cycle , k_effective_exp, std_k_effective 0.9429511921401591   0.9949295051519242  0.006705692703780313
# i == 49
#  keff_cycle , k_effective_exp, std_k_effective 0.9264480000258088   0.9931735691230494  0.0067634060296441
# i == 50
#  keff_cycle , k_effective_exp, std_k_effective 0.9196193787811853   0.9913347143645028  0.0068438194664064865
# i == 51
#  keff_cycle , k_effective_exp, std_k_effective 0.9945091004331542   0.9914121384149578  0.006675259206603165
# i == 52
#  keff_cycle , k_effective_exp, std_k_effective 1.037125511696361   0.9925005520645149  0.006604685347143446
# i == 53
#  keff_cycle , k_effective_exp, std_k_effective 1.0253149731337965   0.9932636781358936  0.0064942517519490095
# i == 54
#  keff_cycle , k_effective_exp, std_k_effective 1.0120427444640978   0.9936904750978982  0.006359276854259413
# i == 55
#  keff_cycle , k_effective_exp, std_k_effective 0.9423352672364099   0.9925492482565318  0.0063202412618289265
# i == 56
#  keff_cycle , k_effective_exp, std_k_effective 0.9990287589535449   0.9926901071847276  0.0061829226233861825
# i == 57
#  keff_cycle , k_effective_exp, std_k_effective 1.057177238294877   0.9940621738040926  0.006203575817631778
# i == 58
#  keff_cycle , k_effective_exp, std_k_effective 1.0324239780265603   0.9948613780587272  0.006125321678125918
# i == 59
#  keff_cycle , k_effective_exp, std_k_effective 0.9714758643210694   0.994384122676326  0.00601796705850603
# i == 60
#  keff_cycle , k_effective_exp, std_k_effective 0.9866220516137509   0.9942288812550746  0.005898422697250965
# i == 61
#  keff_cycle , k_effective_exp, std_k_effective 0.9615786488851212   0.9935886806203696  0.0058169475604012
# i == 62
#  keff_cycle , k_effective_exp, std_k_effective 1.007397100679923   0.9938542271599764  0.005710164224007662
# i == 63
#  keff_cycle , k_effective_exp, std_k_effective 0.9746363078055824   0.9934916249080067  0.005613113368690747
# i == 64
#  keff_cycle , k_effective_exp, std_k_effective 1.0853315354288198   0.9951923639917255  0.005764774726793028
# i == 65
#  keff_cycle , k_effective_exp, std_k_effective 0.9743915222553238   0.9948141668692455  0.005671613661633404
# i == 66
#  keff_cycle , k_effective_exp, std_k_effective 1.0172203101232618   0.9952142765702101  0.005583767605629243
# i == 67
#  keff_cycle , k_effective_exp, std_k_effective 0.9526173429942878   0.9944669619460711  0.005535608254280396
# i == 68
#  keff_cycle , k_effective_exp, std_k_effective 1.0539329587260244   0.995492237752622  0.005535114766157358
# i == 69
#  keff_cycle , k_effective_exp, std_k_effective 1.014286177431855   0.9958107791031175  0.005449807785406788
# i == 70
#  keff_cycle , k_effective_exp, std_k_effective 0.9434859912350944   0.9949386993053171  0.005428712054899948
# i == 71
#  keff_cycle , k_effective_exp, std_k_effective 0.9993435212826123   0.9950109095016662  0.0053394633993698246
# i == 72
#  keff_cycle , k_effective_exp, std_k_effective 0.9386076206096654   0.9941011790356662  0.005330835366783145
# i == 73
#  keff_cycle , k_effective_exp, std_k_effective 1.0086422020600745   0.9943319889249425  0.005250611997718272
# i == 74
#  keff_cycle , k_effective_exp, std_k_effective 1.0269384460004263   0.994841464816747  0.005192972471182306
# i == 75
#  keff_cycle , k_effective_exp, std_k_effective 1.013034089630405   0.9951213513523418  0.005120111995739152
# i == 76
#  keff_cycle , k_effective_exp, std_k_effective 1.0487566012004632   0.995934006653071  0.005107009396519846
# i == 77
#  keff_cycle , k_effective_exp, std_k_effective 1.0570967188025366   0.9968468829538093  0.005112370735306101
# i == 78
#  keff_cycle , k_effective_exp, std_k_effective 0.9678419721340639   0.9964203401476366  0.0050546570189368934
# i == 79
#  keff_cycle , k_effective_exp, std_k_effective 1.0269220239454973   0.9968623935360115  0.005000440169716188
# i == 80
#  keff_cycle , k_effective_exp, std_k_effective 0.9785921365873671   0.9966013898653165  0.004935393938119836
# i == 81
#  keff_cycle , k_effective_exp, std_k_effective 0.9604314925749309   0.9960919546922125  0.004891982571792101
# i == 82
#  keff_cycle , k_effective_exp, std_k_effective 1.00086345583458   0.996158225541412  0.00482401509121997
# i == 83
#  keff_cycle , k_effective_exp, std_k_effective 1.0097340554216006   0.9963441958137433  0.004761107178709364
# i == 84
#  keff_cycle , k_effective_exp, std_k_effective 1.0114013598539027   0.9965476710034753  0.004700733054025321
# i == 85
#  keff_cycle , k_effective_exp, std_k_effective 1.0185901264344313   0.9968415704092214  0.004646936374935492
# i == 86
#  keff_cycle , k_effective_exp, std_k_effective 1.0478175703434378   0.997512307250461  0.004634181908377039
# i == 87
#  keff_cycle , k_effective_exp, std_k_effective 0.9386138335694562   0.9967473920078507  0.004637125015160879
# i == 88
#  keff_cycle , k_effective_exp, std_k_effective 1.0305034521309715   0.9971801620094292  0.0045977017238915925
# i == 89
#  keff_cycle , k_effective_exp, std_k_effective 0.9548050279997635   0.9966437679080411  0.0045707131535804415
# i == 90
#  keff_cycle , k_effective_exp, std_k_effective 0.9847686282175553   0.9964953286619099  0.004515658033310029
# i == 91
#  keff_cycle , k_effective_exp, std_k_effective 0.9650785186860686   0.9961074668103563  0.00447639572346447
# i == 92
#  keff_cycle , k_effective_exp, std_k_effective 0.9880896153283671   0.9960096881337467  0.004422549574721441
# i == 93
#  keff_cycle , k_effective_exp, std_k_effective 1.0005192680592399   0.9960640204220056  0.004369278758003694
# i == 94
#  keff_cycle , k_effective_exp, std_k_effective 1.0217524109359968   0.9963698345947913  0.004327768611284599
# i == 95
#  keff_cycle , k_effective_exp, std_k_effective 0.9675933053309296   0.9960312871916871  0.004289930007569317
# i == 96
#  keff_cycle , k_effective_exp, std_k_effective 0.9507567555007251   0.9955048391487689  0.004272313033003578
# i == 97
#  keff_cycle , k_effective_exp, std_k_effective 0.9772892793194602   0.9952954648978574  0.004228107718660419
# i == 98
#  keff_cycle , k_effective_exp, std_k_effective 1.0086706986180582   0.9954474561901324  0.004182547449588009
# i == 99
#  keff_cycle , k_effective_exp, std_k_effective 1.015917146043066   0.9956774527053339  0.0041416765494102946
# i == 100
#  keff_cycle , k_effective_exp, std_k_effective 1.0921657274627843   0.9967495446470833  0.004233400196525856
# i == 101
#  keff_cycle , k_effective_exp, std_k_effective 1.0224330688780956   0.9970317811770946  0.0041961234093990845
# i == 102
#  keff_cycle , k_effective_exp, std_k_effective 1.0225323548267147   0.9973089613254599  0.00415950836195143
# i == 103
#  keff_cycle , k_effective_exp, std_k_effective 1.0144192929952374   0.9974929433864252  0.004118650717413213
# i == 104
#  keff_cycle , k_effective_exp, std_k_effective 1.035475819300473   0.9978970165344471  0.004094586415076802
# i == 105
#  keff_cycle , k_effective_exp, std_k_effective 1.038244474554711   0.998321726618871  0.00407345747102217
# i == 106
#  keff_cycle , k_effective_exp, std_k_effective 1.0681443169805687   0.9990490452684719  0.004095895448427089
# i == 107
#  keff_cycle , k_effective_exp, std_k_effective 0.9882843861192947   0.9989380694009546  0.004054968661719262
# i == 108
#  keff_cycle , k_effective_exp, std_k_effective 0.9619311338312205   0.9985604476094266  0.004031104354016617
# i == 109
#  keff_cycle , k_effective_exp, std_k_effective 0.9695326990885021   0.9982672380284072  0.004000936807394966
# i == 110
#  keff_cycle , k_effective_exp, std_k_effective 1.122310639506177   0.9995076720431849  0.004150424312651659
# i == 111
#  keff_cycle , k_effective_exp, std_k_effective 1.0118612776065945   0.9996299849695554  0.004110945521527461
# i == 112
#  keff_cycle , k_effective_exp, std_k_effective 1.009243106931139   0.9997242312632963  0.004071533542099278
# i == 113
#  keff_cycle , k_effective_exp, std_k_effective 0.9228999136764466   0.998978364102259  0.004100220997460359
# i == 114
#  keff_cycle , k_effective_exp, std_k_effective 1.041533314208576   0.9993875463148197  0.004081168733314385
# i == 115
#  keff_cycle , k_effective_exp, std_k_effective 1.065558096755704   1.0000177420333045  0.004090944745055561
# i == 116
#  keff_cycle , k_effective_exp, std_k_effective 1.0041675668236036   1.0000568913237788  0.004052356254983595
# i == 117
#  keff_cycle , k_effective_exp, std_k_effective 0.9321572268161881   0.9994223150199696  0.0040641521468113
# i == 118
#  keff_cycle , k_effective_exp, std_k_effective 1.0268628696437778   0.9996763942294493  0.004034354023403224
# i == 119
#  keff_cycle , k_effective_exp, std_k_effective 0.9413090155081668   0.999140913690722  0.004032878545704279
# i == 120
#  keff_cycle , k_effective_exp, std_k_effective 1.0116261234084174   0.9992544155972465  0.003997659436199362
# i == 121
#  keff_cycle , k_effective_exp, std_k_effective 0.9370237960253502   0.998693779384887  0.0040009552511885305
# i == 122
#  keff_cycle , k_effective_exp, std_k_effective 0.990506044315906   0.9986206746074854  0.003965745385678145
# i == 123
#  keff_cycle , k_effective_exp, std_k_effective 1.028683161151071   0.9988867143114109  0.003939486919701457
# i == 124
#  keff_cycle , k_effective_exp, std_k_effective 1.017472172163766   0.9990497446434491  0.003908179006455144
# i == 125
#  keff_cycle , k_effective_exp, std_k_effective 1.0438247398435931   0.999439092427798  0.003893561665252843
# i == 126
#  keff_cycle , k_effective_exp, std_k_effective 0.9933843431799776   0.9993868963135928  0.0038602034436645556
# i == 127
#  keff_cycle , k_effective_exp, std_k_effective 0.9625503902057106   0.9990720543810467  0.003839996771295398
# i == 128
#  keff_cycle , k_effective_exp, std_k_effective 0.9410056442541489   0.9985799661596323  0.0038389843732117095
# i == 129
#  keff_cycle , k_effective_exp, std_k_effective 0.9851855423443309   0.9984674079763104  0.0038082510720334724
# i == 130
#  keff_cycle , k_effective_exp, std_k_effective 1.0180788231735656   0.9986308364362876  0.0037799169504166607
# i == 131
#  keff_cycle , k_effective_exp, std_k_effective 1.0773010476559939   0.9992810034711612  0.003804514134828413
# i == 132
#  keff_cycle , k_effective_exp, std_k_effective 0.9396785941819857   0.9987924591327253  0.0038046970063852995
# i == 133
#  keff_cycle , k_effective_exp, std_k_effective 0.9983373085631153   0.9987887587215902  0.003773639550046781
# i == 134
#  keff_cycle , k_effective_exp, std_k_effective 1.0801604513651237   0.9994449820493606  0.003800171227340777
# i == 135
#  keff_cycle , k_effective_exp, std_k_effective 0.9815299669278326   0.9993016619283884  0.0037723707655094646
# i == 136
#  keff_cycle , k_effective_exp, std_k_effective 0.9317249279990872   0.9987653386432352  0.0037805473734519534
# i == 137
#  keff_cycle , k_effective_exp, std_k_effective 0.962548844522435   0.9984801693981895  0.003761486487504199
# i == 138
#  keff_cycle , k_effective_exp, std_k_effective 0.9453105650342891   0.9980647818640965  0.003755030319764285
# i == 139
#  keff_cycle , k_effective_exp, std_k_effective 1.027245438438404   0.9982909885042075  0.003732668425851761
# i == 140
#  keff_cycle , k_effective_exp, std_k_effective 0.9858411611459501   0.9981952206014516  0.0037050821975275834
# i == 141
#  keff_cycle , k_effective_exp, std_k_effective 0.9484253188529549   0.9978152976873409  0.003696267483725736
# i == 142
#  keff_cycle , k_effective_exp, std_k_effective 1.0158931532368016   0.9979522511384731  0.0036707143173725586
# i == 143
#  keff_cycle , k_effective_exp, std_k_effective 0.9938195329326115   0.997921178069256  0.003643142933600894
# i == 144
#  keff_cycle , k_effective_exp, std_k_effective 0.9761340082552804   0.9977585872497488  0.0036195067809130124
# i == 145
#  keff_cycle , k_effective_exp, std_k_effective 1.0061282303472727   0.9978205846060269  0.0035931304803348664
# i == 146
#  keff_cycle , k_effective_exp, std_k_effective 0.9895244542689102   0.9977595836476657  0.003567134171470012
# i == 147
#  keff_cycle , k_effective_exp, std_k_effective 1.0044451910909933   0.9978083837019964  0.0035413372197413617
# i == 148
#  keff_cycle , k_effective_exp, std_k_effective 1.007030730914098   0.9978752123049827  0.00351621682188534
# i == 149
#  keff_cycle , k_effective_exp, std_k_effective 1.0306911022949805   0.998111297844479  0.0034988027944905377
# i == 150
#  keff_cycle , k_effective_exp, std_k_effective 0.9668337238158997   0.9978878866014179  0.0034808983435797437
# i == 151
#  keff_cycle , k_effective_exp, std_k_effective 1.0094001738067224   0.9979695340284057  0.003457087236140015
# i == 152
#  keff_cycle , k_effective_exp, std_k_effective 1.0170141630156373   0.9981036511339496  0.003435274260403847
# i == 153
#  keff_cycle , k_effective_exp, std_k_effective 0.9394023908708597   0.9976931528104316  0.0034357775886783787
# i == 154
#  keff_cycle , k_effective_exp, std_k_effective 1.0252600590412475   0.9978845896592566  0.003417201102896219
# i == 155
#  keff_cycle , k_effective_exp, std_k_effective 0.9709691585883173   0.9976989659966984  0.003398625283842891
# i == 156
#  keff_cycle , k_effective_exp, std_k_effective 0.9112239574283527   0.997106671417463  0.003426840900019639
# i == 157
#  keff_cycle , k_effective_exp, std_k_effective 1.0009877846167865   0.9971330735480708  0.0034035516263796767
# i == 158
#  keff_cycle , k_effective_exp, std_k_effective 1.0111173606607455   0.9972275619745077  0.0033817967094162548
# i == 159
#  keff_cycle , k_effective_exp, std_k_effective 1.0128151717393916   0.9973321768051445  0.003360652097732338
# i == 160
#  keff_cycle , k_effective_exp, std_k_effective 1.0127847582616698   0.9974351940148546  0.003339761763039792
# i == 161
#  keff_cycle , k_effective_exp, std_k_effective 0.9862389622589385   0.997361046784683  0.0033183988958398656
# i == 162
#  keff_cycle , k_effective_exp, std_k_effective 1.0064622536386174   0.9974209231455642  0.0032970387749870237
# i == 163
#  keff_cycle , k_effective_exp, std_k_effective 0.9945042051625962   0.9974018596293357  0.003275474091464217
# i == 164
#  keff_cycle , k_effective_exp, std_k_effective 0.9732388283437862   0.9972449568287802  0.0032579157217503428
# i == 165
#  keff_cycle , k_effective_exp, std_k_effective 0.9700492669162861   0.9970695007648286  0.0032415805789895906
# i == 166
#  keff_cycle , k_effective_exp, std_k_effective 1.0015313472616452   0.9970981023449363  0.003220861180401107
# i == 167
#  keff_cycle , k_effective_exp, std_k_effective 1.0373472497414935   0.9973544663410927  0.0032105322073023813
# i == 168
#  keff_cycle , k_effective_exp, std_k_effective 1.0623932426630132   0.9977661041659149  0.0032165956932028307
# i == 169
#  keff_cycle , k_effective_exp, std_k_effective 0.9411968229323746   0.9974103225229367  0.0032160416554685703
# i == 170
#  keff_cycle , k_effective_exp, std_k_effective 1.0016657764962893   0.9974369191102701  0.003195988854649754
# i == 171
#  keff_cycle , k_effective_exp, std_k_effective 0.982782325239158   0.9973458967880893  0.0031773799822938918
# i == 172
#  keff_cycle , k_effective_exp, std_k_effective 0.9718936102778971   0.9971887839083967  0.003161611804058924
# i == 173
#  keff_cycle , k_effective_exp, std_k_effective 0.9383038468895579   0.9968275266260727  0.0031628544549752694
# i == 174
#  keff_cycle , k_effective_exp, std_k_effective 1.0150363138939604   0.9969385558167306  0.0031454697699260284
# i == 175
#  keff_cycle , k_effective_exp, std_k_effective 1.0437915346837048   0.9972225132644091  0.003139217239124508
# i == 176
#  keff_cycle , k_effective_exp, std_k_effective 1.0012719508436854   0.997246907466694  0.0031203443413277887
# i == 177
#  keff_cycle , k_effective_exp, std_k_effective 0.9280798196311033   0.9968327332880378  0.003129134654144871
# i == 178
#  keff_cycle , k_effective_exp, std_k_effective 1.0369143579931288   0.9970713143874729  0.0031195896112835644
# i == 179
#  keff_cycle , k_effective_exp, std_k_effective 1.0157435003222357   0.9971818006947791  0.0031030431628589522
# i == 180
#  keff_cycle , k_effective_exp, std_k_effective 1.0232779042516542   0.99733530718629  0.0030885530931395876
# i == 181
#  keff_cycle , k_effective_exp, std_k_effective 1.0076395050374394   0.9973955656532559  0.003071029496232503
# i == 182
#  keff_cycle , k_effective_exp, std_k_effective 0.9938885748100424   0.9973751761716092  0.0030531905482069294
# i == 183
#  keff_cycle , k_effective_exp, std_k_effective 0.9643359302791812   0.997184197871653  0.0030414925227974315
# i == 184
#  keff_cycle , k_effective_exp, std_k_effective 0.9959211870846458   0.9971769391889691  0.0030239708723306708
# i == 185
#  keff_cycle , k_effective_exp, std_k_effective 0.9816447509266921   0.9970881838274704  0.003007951117321206
# i == 186
#  keff_cycle , k_effective_exp, std_k_effective 0.9245570902024534   0.9966760753409646  0.0030190706784577917
# i == 187
#  keff_cycle , k_effective_exp, std_k_effective 0.984122998181225   0.9966051540010791  0.003002802964875841
# i == 188
#  keff_cycle , k_effective_exp, std_k_effective 0.9951934496814078   0.9965972230779349  0.002985896163248596
# i == 189
#  keff_cycle , k_effective_exp, std_k_effective 1.0871245158390008   0.9971029621436391  0.003011931693635072
# i == 190
#  keff_cycle , k_effective_exp, std_k_effective 0.9665717328289627   0.9969333442030021  0.002999950957070841
# i == 191
#  keff_cycle , k_effective_exp, std_k_effective 0.9532613628147022   0.9966920625378733  0.0029930717205546094
# i == 192
#  keff_cycle , k_effective_exp, std_k_effective 1.0109020079024271   0.9967701391607555  0.0029776046525139873
# i == 193
#  keff_cycle , k_effective_exp, std_k_effective 1.038342707660123   0.9969973116662165  0.002969989768351177
# i == 194
#  keff_cycle , k_effective_exp, std_k_effective 0.9790621436370311   0.9968998379269275  0.0029554122667985044
# i == 195
#  keff_cycle , k_effective_exp, std_k_effective 0.9309823202502107   0.9965435270205669  0.002960910757878591
# i == 196
#  keff_cycle , k_effective_exp, std_k_effective 0.9387843328534256   0.9962329937185931  0.0029612758586500323
# i == 197
#  keff_cycle , k_effective_exp, std_k_effective 1.0001757957820152   0.996254078221606  0.00294547305476909
# i == 198
#  keff_cycle , k_effective_exp, std_k_effective 0.8899889530187807   0.9956888381939314  0.0029837915372996327
# i == 199
#  keff_cycle , k_effective_exp, std_k_effective 1.0369191040933567   0.9959069877489548  0.0029759686490078313
# i == 200
#  keff_cycle , k_effective_exp, std_k_effective 0.969751973130163   0.9957693297772771  0.0029634631709313172
# i == 201
#  keff_cycle , k_effective_exp, std_k_effective 1.083786100772749   0.9962301505678293  0.002983707502073979
# i == 202
#  keff_cycle , k_effective_exp, std_k_effective 0.9734445661342795   0.9961114756489046  0.0029704982259509158
# i == 203
#  keff_cycle , k_effective_exp, std_k_effective 1.0357316137877168   0.9963167613387429  0.0029621888805578672
# i == 204
#  keff_cycle , k_effective_exp, std_k_effective 0.9970088321402972   0.9963203287140086  0.0029468824676708635
# i == 205
#  keff_cycle , k_effective_exp, std_k_effective 1.0330072554399683   0.9965084667997828  0.0029377617940058403
# i == 206
#  keff_cycle , k_effective_exp, std_k_effective 1.019407444134851   0.9966252983167985  0.0029250689227657907
# i == 207
#  keff_cycle , k_effective_exp, std_k_effective 0.9964351315997594   0.9966243330035139  0.002910183139301263
# i == 208
#  keff_cycle , k_effective_exp, std_k_effective 1.063967110176324   0.9969644480397403  0.0029153553834471687
# i == 209
#  keff_cycle , k_effective_exp, std_k_effective 1.0164891014825468   0.9970625618761362  0.0029023272155662317
# i == 210
#  keff_cycle , k_effective_exp, std_k_effective 0.9910181484239943   0.9970323398088755  0.002887937258131447
# i == 211
#  keff_cycle , k_effective_exp, std_k_effective 1.0326833753641331   0.9972097081449713  0.0028790023014739746
# i == 212
#  keff_cycle , k_effective_exp, std_k_effective 1.054500755375154   0.9974933271906653  0.0028787198771833807
# i == 213
#  keff_cycle , k_effective_exp, std_k_effective 1.04465026819396   0.9977256273926519  0.002873907778231781
# i == 214
#  keff_cycle , k_effective_exp, std_k_effective 1.0378591703880766   0.9979223604465511  0.0028665442317695926
# i == 215
#  keff_cycle , k_effective_exp, std_k_effective 1.0464120688196004   0.9981588956093465  0.0028623169150952654
# i == 216
#  keff_cycle , k_effective_exp, std_k_effective 0.9966380557074577   0.998151512891376  0.0028483978505638484
# i == 217
#  keff_cycle , k_effective_exp, std_k_effective 1.0678011649396584   0.9984879846404016  0.0028545040728006417
# i == 218
#  keff_cycle , k_effective_exp, std_k_effective 1.0005003143571682   0.9984976593025015  0.00284076382092623
# i == 219
#  keff_cycle , k_effective_exp, std_k_effective 1.0149397516338237   0.9985763296007374  0.0028282333363128893
# i == 220
#  keff_cycle , k_effective_exp, std_k_effective 0.9677102248112645   0.998429348149359  0.002818568309522809
# i == 221
#  keff_cycle , k_effective_exp, std_k_effective 0.9649194019669393   0.9982705332385418  0.0028096704096083934
# i == 222
#  keff_cycle , k_effective_exp, std_k_effective 1.0067554514204937   0.9983105564375133  0.002796672242350822
# i == 223
#  keff_cycle , k_effective_exp, std_k_effective 0.9810273747322233   0.9982294147393664  0.002784693782005934
# i == 224
#  keff_cycle , k_effective_exp, std_k_effective 0.9745681551373214   0.998118848105712  0.002773855132399397
# i == 225
#  keff_cycle , k_effective_exp, std_k_effective 1.0146504742858624   0.998195739390271  0.0027619938340218246
# i == 226
#  keff_cycle , k_effective_exp, std_k_effective 1.069112386242875   0.9985240571997737  0.0027687121999219622
# i == 227
#  keff_cycle , k_effective_exp, std_k_effective 1.0781151474607213   0.998890836417566  0.0027802233737451937
# i == 228
#  keff_cycle , k_effective_exp, std_k_effective 0.9989309670289687   0.9988910205029394  0.002767440675957642
# i == 229
#  keff_cycle , k_effective_exp, std_k_effective 1.0275394693049127   0.9990218353376517  0.0027578792024713287
# i == 230
#  keff_cycle , k_effective_exp, std_k_effective 1.053095240345582   0.9992676235422332  0.0027562955234211434
# i == 231
#  keff_cycle , k_effective_exp, std_k_effective 1.0034278303019197   0.9992864480072091  0.002743859826661372
# i == 232
#  keff_cycle , k_effective_exp, std_k_effective 1.0295676712749127   0.9994228499138205  0.002734875774332466
# i == 233
#  keff_cycle , k_effective_exp, std_k_effective 1.0404041871384249   0.9996066227264868  0.0027287793648692344
# i == 234
#  keff_cycle , k_effective_exp, std_k_effective 1.055795859975445   0.9998574675356339  0.002728126771810963
# i == 235
#  keff_cycle , k_effective_exp, std_k_effective 0.9282277496354342   0.9995391132338551  0.002734569075256616
# i == 236
#  keff_cycle , k_effective_exp, std_k_effective 0.9202682903019904   0.9991883573801743  0.002744944785053117
# i == 237
#  keff_cycle , k_effective_exp, std_k_effective 0.9315123083029052   0.9988902250053845  0.002749039754377529
# i == 238
#  keff_cycle , k_effective_exp, std_k_effective 1.0132903545584653   0.9989533834683367  0.0027376846353887488
# i == 239
#  keff_cycle , k_effective_exp, std_k_effective 1.0283955270462972   0.9990819517809042  0.002728733988871919
# i == 240
#  keff_cycle , k_effective_exp, std_k_effective 0.9750985077045223   0.9989776759370939  0.002718844405553508
# i == 241
#  keff_cycle , k_effective_exp, std_k_effective 0.9887200889370884   0.9989332707985658  0.0027074131053679605
# i == 242
#  keff_cycle , k_effective_exp, std_k_effective 0.9324554723940496   0.9986467285640636  0.002710904236801237
# i == 243
#  keff_cycle , k_effective_exp, std_k_effective 0.9522028048749039   0.9984473984194748  0.0027065943041571245
# i == 244
#  keff_cycle , k_effective_exp, std_k_effective 1.0375889311296014   0.998614669926783  0.002700188894870199
# i == 245
#  keff_cycle , k_effective_exp, std_k_effective 0.9442741395132002   0.9983834336271508  0.0026985994626151657
# i == 246
#  keff_cycle , k_effective_exp, std_k_effective 1.0446919411894848   0.9985796561168216  0.0026942952213572353
# i == 247
#  keff_cycle , k_effective_exp, std_k_effective 1.0041833074257411   0.9986033002151715  0.0026830069857964765
# i == 248
#  keff_cycle , k_effective_exp, std_k_effective 0.9780578074922108   0.9985169746154952  0.002673104333127214
# i == 249
#  keff_cycle , k_effective_exp, std_k_effective 1.0797787623715587   0.998856982095646  0.002683523242665405
# i == 250
#  keff_cycle , k_effective_exp, std_k_effective 1.0267282123316628   0.9989731122216294  0.0026748406292345078
# i == 251
#  keff_cycle , k_effective_exp, std_k_effective 0.9803941515501571   0.9988960210985113  0.0026648339026233846
# i == 252
#  keff_cycle , k_effective_exp, std_k_effective 1.0572764535083468   0.9991372625547502  0.002664741715568682
# i == 253
#  keff_cycle , k_effective_exp, std_k_effective 1.026318713088161   0.9992491203758753  0.002656109445418801
# i == 254
#  keff_cycle , k_effective_exp, std_k_effective 1.0618778619229943   0.9995057955461505  0.0026576253192257615
# i == 255
#  keff_cycle , k_effective_exp, std_k_effective 0.9835424597384549   0.999440639073466  0.002647557513309692
# i == 256
#  keff_cycle , k_effective_exp, std_k_effective 1.0538689428465327   0.9996618923408361  0.0026460395869164757
# i == 257
#  keff_cycle , k_effective_exp, std_k_effective 1.0184579127581235   0.9997379895894891  0.0026364035678643413
# i == 258
#  keff_cycle , k_effective_exp, std_k_effective 0.9708135570100529   0.9996213588129591  0.0026283403685901227
# i == 259
#  keff_cycle , k_effective_exp, std_k_effective 0.9903084711318939   0.9995839576576134  0.0026180306731396485
# i == 260
#  keff_cycle , k_effective_exp, std_k_effective 1.002279326220643   0.9995947391318656  0.002607559811172716
# i == 261
#  keff_cycle , k_effective_exp, std_k_effective 1.01209520843568   0.9996445417984147  0.0025976278105258703
# i == 262
#  keff_cycle , k_effective_exp, std_k_effective 1.0232855641575724   0.999738355379205  0.0025889994769272193
# i == 263
#  keff_cycle , k_effective_exp, std_k_effective 1.0498574539983019   0.999936454583233  0.0025863437686800715
# i == 264
#  keff_cycle , k_effective_exp, std_k_effective 1.0341542181625607   1.000071170187876  0.0025796611641454464
# i == 265
#  keff_cycle , k_effective_exp, std_k_effective 1.0290753677922972   1.0001849121392659  0.0025720411362318
# i == 266
#  keff_cycle , k_effective_exp, std_k_effective 0.9741125568226885   1.0000830670013106  0.0025639979056969187
# i == 267
#  keff_cycle , k_effective_exp, std_k_effective 1.0338650968771237   1.000214514588376  0.002557382163851225
# i == 268
#  keff_cycle , k_effective_exp, std_k_effective 1.0238843083118159   1.0003062579749011  0.0025491020240016905
# i == 269
#  keff_cycle , k_effective_exp, std_k_effective 1.0486160449617865   1.0004927822489817  0.0025460823703206212
# i == 270
#  keff_cycle , k_effective_exp, std_k_effective 1.0476378675246587   1.000674109500042  0.0025427444526005824
# i == 271
#  keff_cycle , k_effective_exp, std_k_effective 0.8808122566780306   1.000214868684632  0.0025742779644584712
# i == 272
#  keff_cycle , k_effective_exp, std_k_effective 0.9965336025221   1.0002008180504238  0.002564472144904265
# i == 273
#  keff_cycle , k_effective_exp, std_k_effective 0.9588092727179605   1.0000434357487795  0.0025595458643740327
# i == 274
#  keff_cycle , k_effective_exp, std_k_effective 0.9668886371206684   0.9999178493903399  0.002552923048939607
# i == 275
#  keff_cycle , k_effective_exp, std_k_effective 0.9776833586852968   0.9998339456518303  0.0025446547673804378
# i == 276
#  keff_cycle , k_effective_exp, std_k_effective 0.9861065263663061   0.999782338812411  0.0025355955762554967
# i == 277
#  keff_cycle , k_effective_exp, std_k_effective 0.9562721553702397   0.9996193793238636  0.0025313319780718565
# i == 278
#  keff_cycle , k_effective_exp, std_k_effective 0.9465303499749151   0.9994212859307705  0.0025296371982610655
# i == 279
#  keff_cycle , k_effective_exp, std_k_effective 1.0346528573777636   0.9995522583153318  0.0025236167366878013
# i == 280
#  keff_cycle , k_effective_exp, std_k_effective 0.9684655523906476   0.9994371223674625  0.0025168874822787536
# i == 281
#  keff_cycle , k_effective_exp, std_k_effective 0.9797327021511891   0.999364412329764  0.0025086368066640926
# i == 282
#  keff_cycle , k_effective_exp, std_k_effective 0.9650832382462706   0.9992383786015159  0.002502572510019995
# i == 283
#  keff_cycle , k_effective_exp, std_k_effective 1.0534099591934472   0.999436809299655  0.002501272093248908
# i == 284
#  keff_cycle , k_effective_exp, std_k_effective 0.9468758978203508   0.9992449811555698  0.0024994985986793315
# i == 285
#  keff_cycle , k_effective_exp, std_k_effective 0.9709021314076868   0.9991419162473957  0.002492524685051132
# i == 286
#  keff_cycle , k_effective_exp, std_k_effective 1.0460672653486187   0.9993119356281972  0.0024892903567441636
# i == 287
#  keff_cycle , k_effective_exp, std_k_effective 1.000131297901481   0.9993148936147432  0.002480289232662278
# i == 288
#  keff_cycle , k_effective_exp, std_k_effective 0.9254438935803924   0.999049170593037  0.0024855956224793994
# i == 289
#  keff_cycle , k_effective_exp, std_k_effective 0.9483434619978995   0.998867429702015  0.002483329877634434
# i == 290
#  keff_cycle , k_effective_exp, std_k_effective 0.9980866879161484   0.9988646413384942  0.0024744465190307346
# i == 291
#  keff_cycle , k_effective_exp, std_k_effective 1.0315319920767831   0.9989808952557123  0.002468364092277807
# i == 292
#  keff_cycle , k_effective_exp, std_k_effective 1.0401439981970124   0.9991268637058588  0.002463923006499888
# i == 293
#  keff_cycle , k_effective_exp, std_k_effective 1.0184288540888   0.9991950686188729  0.002456148303341209
# i == 294
#  keff_cycle , k_effective_exp, std_k_effective 0.9751454038798796   0.9991103867007778  0.0024489491547448916
# i == 295
#  keff_cycle , k_effective_exp, std_k_effective 1.0810104936700384   0.9993977554971611  0.002457202903144502
# i == 296
#  keff_cycle , k_effective_exp, std_k_effective 0.9750899598725231   0.9993127632047674  0.0024500708350857175
# i == 297
#  keff_cycle , k_effective_exp, std_k_effective 0.9828878309958928   0.9992555334758165  0.0024421897247606976
# i == 298
#  keff_cycle , k_effective_exp, std_k_effective 1.037210671375481   0.9993873221490792  0.002437260802836998
# i == 299
#  keff_cycle , k_effective_exp, std_k_effective 0.9998618529683307   0.9993889641242323  0.0024288132880612052
# i == 300
#  keff_cycle , k_effective_exp, std_k_effective 1.0147933965440923   0.9994420828567144  0.0024210063827519194
# i == 301
#  keff_cycle , k_effective_exp, std_k_effective 0.954038571170575   0.9992860570433602  0.0024177122045544916
# i == 302
#  keff_cycle , k_effective_exp, std_k_effective 1.012217277824275   0.9993303420460344  0.0024098250855369395
# i == 303
#  keff_cycle , k_effective_exp, std_k_effective 1.0227420749411196   0.9994102455712737  0.0024029152163770697
# i == 304
#  keff_cycle , k_effective_exp, std_k_effective 1.0018290631899682   0.9994184728420855  0.0023947422205866766
# i == 305
#  keff_cycle , k_effective_exp, std_k_effective 1.0010835103753832   0.9994241170371138  0.002386617318662522
# i == 306
#  keff_cycle , k_effective_exp, std_k_effective 0.9264442342322128   0.9991775633789891  0.0023912851849904222
# i == 307
#  keff_cycle , k_effective_exp, std_k_effective 1.0551309051599416   0.9993659584691608  0.0023906548991277283
# i == 308
#  keff_cycle , k_effective_exp, std_k_effective 1.0254930098005073   0.9994536331380579  0.0023842316247136676
# i == 309
#  keff_cycle , k_effective_exp, std_k_effective 0.9839452694359807   0.9994017657009273  0.002376810227103797
# i == 310
#  keff_cycle , k_effective_exp, std_k_effective 0.952322436318614   0.9992448346029863  0.0023740667035269
# i == 311
#  keff_cycle , k_effective_exp, std_k_effective 0.9634120292535852   0.999125788738038  0.0023691591008814213
# i == 312
#  keff_cycle , k_effective_exp, std_k_effective 1.0484181165208282   0.999289008366458  0.002366935544305927
# i == 313
#  keff_cycle , k_effective_exp, std_k_effective 0.9848595422497665   0.9992413863660728  0.0023595915524362242
# i == 314
#  keff_cycle , k_effective_exp, std_k_effective 1.0147556011685062   0.9992924199673967  0.0023523705702553467
# i == 315
#  keff_cycle , k_effective_exp, std_k_effective 1.0118037385647896   0.9993334406841093  0.0023450040057963876
# i == 316
#  keff_cycle , k_effective_exp, std_k_effective 1.0391844982024292   0.9994636728982215  0.0023409533857239053
# i == 317
#  keff_cycle , k_effective_exp, std_k_effective 1.029798808511147   0.9995624844148759  0.002335406974255486
# i == 318
#  keff_cycle , k_effective_exp, std_k_effective 1.0095737020316322   0.9995949883681771  0.002328039054977846
# i == 319
#  keff_cycle , k_effective_exp, std_k_effective 0.9769666138206894   0.9995217573825865  0.002321647955266436
# i == 320
#  keff_cycle , k_effective_exp, std_k_effective 0.9811081516423716   0.9994623586543924  0.0023149088375040354
# i == 321
#  keff_cycle , k_effective_exp, std_k_effective 0.9999541476882036   0.9994639399696136  0.0023074539369966375
# i == 322
#  keff_cycle , k_effective_exp, std_k_effective 1.02231900154376   0.9995371933720947  0.0023012125769225687
# i == 323
#  keff_cycle , k_effective_exp, std_k_effective 0.9632683011303708   0.9994213183170093  0.0022967735598031776
# i == 324
#  keff_cycle , k_effective_exp, std_k_effective 1.001872232047426   0.9994291237747496  0.002289460615298521
# i == 325
#  keff_cycle , k_effective_exp, std_k_effective 0.9770866075770598   0.9993581951518998  0.0022832828534029726
# i == 326
#  keff_cycle , k_effective_exp, std_k_effective 0.9828660535719203   0.9993060048304441  0.0022766440957300944
# i == 327
#  keff_cycle , k_effective_exp, std_k_effective 0.9776281515508751   0.9992376204352406  0.0022704809545883065
# i == 328
#  keff_cycle , k_effective_exp, std_k_effective 1.0000420433878843   0.9992401500671672  0.002263331229341671
# i == 329
#  keff_cycle , k_effective_exp, std_k_effective 0.9544838748762362   0.9990998482640608  0.0022605830679993046
# i == 330
#  keff_cycle , k_effective_exp, std_k_effective 1.0162608362012242   0.9991534763513645  0.0022541456930015
# i == 331
#  keff_cycle , k_effective_exp, std_k_effective 1.052404165099036   0.9993193663474632  0.0022532274404822427
# i == 332
#  keff_cycle , k_effective_exp, std_k_effective 1.0041639855697515   0.9993344117487747  0.002246269327262906
# i == 333
#  keff_cycle , k_effective_exp, std_k_effective 1.0408451651326964   0.9994629280131211  0.0022429889513843346
# i == 334
#  keff_cycle , k_effective_exp, std_k_effective 0.9489072873434288   0.9993068920851282  0.0022414930503533857
# i == 335
#  keff_cycle , k_effective_exp, std_k_effective 1.1260914270353688   0.9996969983465136  0.002268381642388501
# i == 336
#  keff_cycle , k_effective_exp, std_k_effective 1.0345351216260874   0.9998038637553467  0.00226393632139996
# i == 337
#  keff_cycle , k_effective_exp, std_k_effective 1.0213384607344196   0.99986971879198  0.0022579629080382167
# i == 338
#  keff_cycle , k_effective_exp, std_k_effective 0.971338156244124   0.9997827323207975  0.0022527484006752098
# i == 339
#  keff_cycle , k_effective_exp, std_k_effective 0.9887186496385919   0.9997491028901525  0.0022461424685959242
# i == 340
#  keff_cycle , k_effective_exp, std_k_effective 0.9417307655391   0.9995732897466644  0.0022462167187714344
# i == 341
#  keff_cycle , k_effective_exp, std_k_effective 0.9648327018086642   0.9994683332876373  0.002241878467781418
# i == 342
#  keff_cycle , k_effective_exp, std_k_effective 1.011973610693708   0.9995059997858483  0.002235432979561345
# i == 343
#  keff_cycle , k_effective_exp, std_k_effective 1.00299582304831   0.9995164797355854  0.0022287344971628474
# i == 344
#  keff_cycle , k_effective_exp, std_k_effective 1.0569704840597012   0.9996884977126038  0.002228699976807426
# i == 345
#  keff_cycle , k_effective_exp, std_k_effective 1.0099479225176686   0.9997191228612756  0.0022222482166899624
# i == 346
#  keff_cycle , k_effective_exp, std_k_effective 1.0292519658131931   0.999807018227204  0.002217367261056707
# i == 347
#  keff_cycle , k_effective_exp, std_k_effective 0.9774002013182945   0.9997405291562577  0.0022117773473384187
# i == 348
#  keff_cycle , k_effective_exp, std_k_effective 0.9415939326548686   0.9995684978056619  0.002211923894854037
# i == 349
#  keff_cycle , k_effective_exp, std_k_effective 0.9307343691842073   0.999365447278755  0.002214717113579597
# i == 350
#  keff_cycle , k_effective_exp, std_k_effective 0.9680564115233216   0.9992733618794742  0.0022101128564172407
# i == 351
#  keff_cycle , k_effective_exp, std_k_effective 0.9991464412499028   0.9992729896782144  0.002203622087177678
# i == 352
#  keff_cycle , k_effective_exp, std_k_effective 1.0204374330019343   0.9993348740154183  0.0021980406283995104
# i == 353
#  keff_cycle , k_effective_exp, std_k_effective 1.035266570705626   0.9994396311486259  0.002194125186473008
# i == 354
#  keff_cycle , k_effective_exp, std_k_effective 0.9535950818558055   0.9993063621099839  0.002191792992269107
# i == 355
#  keff_cycle , k_effective_exp, std_k_effective 1.0293432219162075   0.9993934254717411  0.002187164266032735
# i == 356
#  keff_cycle , k_effective_exp, std_k_effective 0.9405052478587158   0.9992232284266168  0.002187465014072999
# i == 357
#  keff_cycle , k_effective_exp, std_k_effective 1.0344643800791886   0.9993247879414657  0.002183515114157862
# i == 358
#  keff_cycle , k_effective_exp, std_k_effective 0.9962420005061438   0.9993159293568815  0.002177249625953543
# i == 359
#  keff_cycle , k_effective_exp, std_k_effective 0.9913209050971533   0.9992930209779137  0.002171122985964922
# i == 360
#  keff_cycle , k_effective_exp, std_k_effective 1.0082319691119042   0.9993185608297253  0.0021650615342196588
# i == 361
#  keff_cycle , k_effective_exp, std_k_effective 0.9909554656122251   0.9992947343476241  0.0021590159321396366
# i == 362
#  keff_cycle , k_effective_exp, std_k_effective 0.9581427269402409   0.9991778252356713  0.00215604559174244
# i == 363
#  keff_cycle , k_effective_exp, std_k_effective 1.0102019448036703   0.9992090550361472  0.0021501559475911244
# i == 364
#  keff_cycle , k_effective_exp, std_k_effective 0.923656291198083   0.998995629149599  0.00215466971949453
# i == 365
#  keff_cycle , k_effective_exp, std_k_effective 1.0303169746086724   0.9990838582917374  0.0021504023994724
# i == 366
#  keff_cycle , k_effective_exp, std_k_effective 0.9717768581846705   0.9990071532352569  0.002145724894395112
# i == 367
#  keff_cycle , k_effective_exp, std_k_effective 1.0509897577460559   0.9991527627717016  0.0021446547471178014
# i == 368
#  keff_cycle , k_effective_exp, std_k_effective 1.007968835473608   0.9991773886731036  0.0021387974758976087
# i == 369
#  keff_cycle , k_effective_exp, std_k_effective 0.9882560515787476   0.9991469671213087  0.0021330484492246326
# i == 370
#  keff_cycle , k_effective_exp, std_k_effective 0.9745258303959164   0.9990785750748492  0.0021282142656459326
# i == 371
#  keff_cycle , k_effective_exp, std_k_effective 1.0572697264398585   0.9992397693999602  0.0021284234819542035
# i == 372
#  keff_cycle , k_effective_exp, std_k_effective 0.9849744712179896   0.999200362498905  0.002122901497381896
# i == 373
#  keff_cycle , k_effective_exp, std_k_effective 0.9685487109285005   0.9991159226874161  0.0021187285071463734
# i == 374
#  keff_cycle , k_effective_exp, std_k_effective 1.034271540165904   0.9992125040541152  0.0021151060386189833
# i == 375
#  keff_cycle , k_effective_exp, std_k_effective 1.0256361661968034   0.9992848976490267  0.002110545215681353
# i == 376
#  keff_cycle , k_effective_exp, std_k_effective 0.9519053338460909   0.9991554452889094  0.002108747977193404
# i == 377
#  keff_cycle , k_effective_exp, std_k_effective 0.9352677268708744   0.9989813643122935  0.002110186929389597
# i == 378
#  keff_cycle , k_effective_exp, std_k_effective 1.0158770137964497   0.999027276403283  0.002104945679593356
# i == 379
#  keff_cycle , k_effective_exp, std_k_effective 0.9744425284520912   0.9989606510700819  0.002100290478217058
# i == 380
#  keff_cycle , k_effective_exp, std_k_effective 0.9495989037855047   0.9988272409422857  0.0020988506193041195
# i == 381
#  keff_cycle , k_effective_exp, std_k_effective 0.9724745251085545   0.9987562093632191  0.00209439056507245
# i == 382
#  keff_cycle , k_effective_exp, std_k_effective 0.9979537192606035   0.9987540521317604  0.0020887540091599124
# i == 383
#  keff_cycle , k_effective_exp, std_k_effective 1.0372481081682512   0.9988572533543782  0.0020857013864201464
# i == 384
#  keff_cycle , k_effective_exp, std_k_effective 0.9916516662511887   0.9988379870787013  0.002080206390483215
# i == 385
#  keff_cycle , k_effective_exp, std_k_effective 0.9735614224047119   0.9987705829062373  0.0020757464288287688
# i == 386
#  keff_cycle , k_effective_exp, std_k_effective 1.052711314111064   0.9989140422977394  0.0020751831469015733
# i == 387
#  keff_cycle , k_effective_exp, std_k_effective 0.9723032626916799   0.9988434566754423  0.0020708746652075495
# i == 388
#  keff_cycle , k_effective_exp, std_k_effective 1.0423324221679582   0.9989585068487028  0.0020685907834594565
# i == 389
#  keff_cycle , k_effective_exp, std_k_effective 1.026346867272909   0.999030771651933  0.0020643907571790757
# i == 390
#  keff_cycle , k_effective_exp, std_k_effective 1.0431685149064942   0.9991469236078659  0.0020622246305340326
# i == 391
#  keff_cycle , k_effective_exp, std_k_effective 1.0456141247807382   0.9992688847658  0.002060417602481841
# i == 392
#  keff_cycle , k_effective_exp, std_k_effective 0.9803653775261383   0.9992193991447538  0.0020556124910540447
# i == 393
#  keff_cycle , k_effective_exp, std_k_effective 0.9913395392421818   0.9991988250980107  0.002050341558760151
# i == 394
#  keff_cycle , k_effective_exp, std_k_effective 1.0338777765577638   0.9992891348674372  0.002046988286944804
# i == 395
#  keff_cycle , k_effective_exp, std_k_effective 1.0027900752887542   0.9992982282191809  0.002041684761553974
# i == 396
#  keff_cycle , k_effective_exp, std_k_effective 0.9804818236292377   0.9992494810570308  0.002036971925846639
# i == 397
#  keff_cycle , k_effective_exp, std_k_effective 1.0182853262942622   0.999298669287618  0.002032296959686343
# i == 398
#  keff_cycle , k_effective_exp, std_k_effective 1.034184346963087   0.9993885808280186  0.0020290453832481972
# i == 399
#  keff_cycle , k_effective_exp, std_k_effective 0.9689098000374735   0.9993102292064491  0.002025338717195955
# i == 400
#  keff_cycle , k_effective_exp, std_k_effective 0.9636422703686135   0.9992187729017367  0.002022208024266246
# i == 401
#  keff_cycle , k_effective_exp, std_k_effective 1.0732333424638298   0.9994080684760643  0.0020258926039992595
# i == 402
#  keff_cycle , k_effective_exp, std_k_effective 0.9986309289884255   0.9994060859773712  0.002020718874296783
# i == 403
#  keff_cycle , k_effective_exp, std_k_effective 0.975116119113524   0.9993442794459111  0.0020165179491711026
# i == 404
#  keff_cycle , k_effective_exp, std_k_effective 1.028397389328976   0.9994180183034823  0.0020127445727409848
# i == 405
#  keff_cycle , k_effective_exp, std_k_effective 1.0563997103041813   0.9995622757515853  0.002012818626092504
# i == 406
#  keff_cycle , k_effective_exp, std_k_effective 0.949084593853072   0.9994348068579022  0.002011771688878161
# i == 407
#  keff_cycle , k_effective_exp, std_k_effective 1.0245294383462902   0.9994980175165631  0.0020076931715443023
# i == 408
#  keff_cycle , k_effective_exp, std_k_effective 0.9785928561655289   0.9994454919855303  0.0020033310674818262
# i == 409
#  keff_cycle , k_effective_exp, std_k_effective 1.0392037612061404   0.9995451367705444  0.002000786715236172
# i == 410
#  keff_cycle , k_effective_exp, std_k_effective 1.0390207681026538   0.9996438258488746  0.001998217024411488
# i == 411
#  keff_cycle , k_effective_exp, std_k_effective 0.9715474842587388   0.9995737601591236  0.0019944588006699554
# i == 412
#  keff_cycle , k_effective_exp, std_k_effective 0.9888818764781426   0.9995471634335491  0.0019896690467842947
# i == 413
#  keff_cycle , k_effective_exp, std_k_effective 0.9321843015080102   0.9993800099300117  0.0019917521542947322
# i == 414
#  keff_cycle , k_effective_exp, std_k_effective 1.0329955267619362   0.9994632166548432  0.0019885575198889975
# i == 415
#  keff_cycle , k_effective_exp, std_k_effective 1.0431169263325792   0.9995710035923191  0.0019865677247722048
# i == 416
#  keff_cycle , k_effective_exp, std_k_effective 1.0048825326152384   0.9995840861761194  0.0019817118438824038
# i == 417
#  keff_cycle , k_effective_exp, std_k_effective 0.9855375200880148   0.9995495737287284  0.0019771380200651564
# i == 418
# ...
#  keff_cycle , k_effective_exp, std_k_effective 0.9648109058176918   0.9985621549961679  0.0016149242413588591
# i == 595
#  keff_cycle , k_effective_exp, std_k_effective 0.9991860834469313   0.9985632215405282  0.0016121616764026275
# i == 596
#  keff_cycle , k_effective_exp, std_k_effective 1.0482179238397042   0.9986479565273869  0.0016116372913669468
# i == 597
#  keff_cycle , k_effective_exp, std_k_effective 1.0079603439240923   0.9986638209011461  0.0016089676127306748
# i == 598
#  keff_cycle , k_effective_exp, std_k_effective 1.0102913200468062   0.9986835955595571  0.0016063506630677705
# i == 599
#  keff_cycle , k_effective_exp, std_k_effective 1.0212667869277843   0.9987219371408275  0.0016040793894467294
# i == 600
#  keff_cycle , k_effective_exp, std_k_effective 1.0352569847799964   0.9987838609503853  0.0016025551386209798
# i == 601
#  keff_cycle , k_effective_exp, std_k_effective 1.0522713396337657   0.9988743642984113  0.0016023990931721124
# i == 602
#  keff_cycle , k_effective_exp, std_k_effective 1.0048261622115238   0.9988844180111024  0.0015997216403805619
# i == 603
#  keff_cycle , k_effective_exp, std_k_effective 1.0218421722986728   0.9989231326051792  0.0015974908720780307
# i == 604
#  keff_cycle , k_effective_exp, std_k_effective 0.9673814809957961   0.9988700321815943  0.0015956829966867422
# i == 605
#  keff_cycle , k_effective_exp, std_k_effective 0.9719983450415756   0.9988248696821993  0.0015936389828313821
# i == 606
#  keff_cycle , k_effective_exp, std_k_effective 1.0004138955244035   0.9988275358329413  0.0015909650789307324
# i == 607
#  keff_cycle , k_effective_exp, std_k_effective 1.05066076051467   0.9989143586548537  0.0015906691842382473
# i == 608
#  keff_cycle , k_effective_exp, std_k_effective 1.022594693694511   0.998953957877328  0.0015885006293939758
# i == 609
#  keff_cycle , k_effective_exp, std_k_effective 1.058668239725695   0.9990536478303302  0.001588976771454684
# i == 610
#  keff_cycle , k_effective_exp, std_k_effective 0.9324844847897512   0.9989426992252626  0.0015902014387874247
# i == 611
#  keff_cycle , k_effective_exp, std_k_effective 1.025589623326435   0.9989870368693577  0.0015881723245299195
# i == 612
#  keff_cycle , k_effective_exp, std_k_effective 1.0327443144568464   0.9990431120812971  0.0015865232605838297
# i == 613
#  keff_cycle , k_effective_exp, std_k_effective 0.984788418757291   0.9990194724572108  0.0015840664265014469
# i == 614
#  keff_cycle , k_effective_exp, std_k_effective 0.9864452322803353   0.9989986541787722  0.0015815786464804292
# i == 615
#  keff_cycle , k_effective_exp, std_k_effective 1.0272169134973905   0.999045295929712  0.0015796510395422725
# i == 616
#  keff_cycle , k_effective_exp, std_k_effective 0.9761676612156001   0.9990075440572466  0.0015774939954335606
# i == 617
#  keff_cycle , k_effective_exp, std_k_effective 1.0207595888844043   0.999043379386451  0.001575300662493771
# i == 618
#  keff_cycle , k_effective_exp, std_k_effective 1.0035312587728562   0.9990507607670209  0.0015727248950976407
# i == 619
#  keff_cycle , k_effective_exp, std_k_effective 0.9800236722975455   0.9990195176004043  0.0015704511128861152
# i == 620
#  keff_cycle , k_effective_exp, std_k_effective 1.035784253283558   0.9990797876589013  0.0015690324705565663
# i == 621
#  keff_cycle , k_effective_exp, std_k_effective 1.0008634870793087   0.9990827069705549  0.0015664651113354003
# i == 622
#  keff_cycle , k_effective_exp, std_k_effective 1.0087695707305686   0.9990985351793131  0.001563983529539596
# i == 623
#  keff_cycle , k_effective_exp, std_k_effective 0.9370575387471299   0.998997326375998  0.001564706724364512
# i == 624
#  keff_cycle , k_effective_exp, std_k_effective 0.9335368846015344   0.9988907132786453  0.001565790070219005
# i == 625
#  keff_cycle , k_effective_exp, std_k_effective 1.0201253448216911   0.998925241134813  0.0015636232645534708
# i == 626
#  keff_cycle , k_effective_exp, std_k_effective 1.0056999799016322   0.9989362390873564  0.0015611215916413448
# i == 627
#  keff_cycle , k_effective_exp, std_k_effective 1.0084647404672844   0.998951682363499  0.0015586658650009128
# i == 628
#  keff_cycle , k_effective_exp, std_k_effective 0.9363447082137413   0.998850376580085  0.0015594357561099501
# i == 629
#  keff_cycle , k_effective_exp, std_k_effective 1.0081032433258073   0.9988653246685272  0.0015569861929134276
# i == 630
#  keff_cycle , k_effective_exp, std_k_effective 1.0151913189525907   0.9988916569173725  0.0015546959100999713
# i == 631
#  keff_cycle , k_effective_exp, std_k_effective 1.0587950107794524   0.9989881196450087  0.0015551848623471538
# i == 632
#  keff_cycle , k_effective_exp, std_k_effective 0.9783035071695709   0.9989548646410289  0.0015530386352663854
# i == 633
#  keff_cycle , k_effective_exp, std_k_effective 0.9841450433974187   0.9989310928573314  0.0015507260074175025
# i == 634
#  keff_cycle , k_effective_exp, std_k_effective 0.9696117789741977   0.9988841067773905  0.0015489516797020505
# i == 635
#  keff_cycle , k_effective_exp, std_k_effective 0.9525299785264244   0.9988099401721889  0.0015482488130786859
# i == 636
#  keff_cycle , k_effective_exp, std_k_effective 0.9497760234843301   0.998731611231793  0.0015477569012863326
# i == 637
#  keff_cycle , k_effective_exp, std_k_effective 1.0098797541648763   0.9987493913640627  0.0015453887039256567
# i == 638
#  keff_cycle , k_effective_exp, std_k_effective 0.9493403633543621   0.9986707145678689  0.0015449305707408256
# i == 639
#  keff_cycle , k_effective_exp, std_k_effective 1.0760094738175112   0.9987936696700147  0.0015473652455313069
# i == 640
#  keff_cycle , k_effective_exp, std_k_effective 1.0456468257978815   0.9988680397591065  0.001546696168093308
# i == 641
#  keff_cycle , k_effective_exp, std_k_effective 1.0081708076156772   0.9988827826558682  0.0015443134138468846
# i == 642
#  keff_cycle , k_effective_exp, std_k_effective 1.0378524083615728   0.9989444434560354  0.0015431003888795743
# i == 643
#  keff_cycle , k_effective_exp, std_k_effective 0.9991414796643896   0.9989447547296664  0.0015406607343891967
# i == 644
#  keff_cycle , k_effective_exp, std_k_effective 1.017278129225712   0.9989736717241396  0.0015385005303588716
# i == 645
#  keff_cycle , k_effective_exp, std_k_effective 1.042393100235272   0.999042048776913  0.0015375969029351928
# i == 646
#  keff_cycle , k_effective_exp, std_k_effective 1.0020144729903167   0.9990467223998901  0.0015351845081787955
# i == 647
#  keff_cycle , k_effective_exp, std_k_effective 0.9924451415379988   0.9990363588506564  0.001532807625909196
# i == 648
#  keff_cycle , k_effective_exp, std_k_effective 0.9568230493716281   0.9989701937887772  0.0015318328342702402
# i == 649
#  keff_cycle , k_effective_exp, std_k_effective 0.9420292380014172   0.9988810843118017  0.0015320274168734702
# i == 650
#  keff_cycle , k_effective_exp, std_k_effective 1.056420168179642   0.9989709891303452  0.0015322715718600359
# i == 651
#  keff_cycle , k_effective_exp, std_k_effective 0.9734888146225003   0.9989312353479617  0.0015303956772252949
# i == 652
#  keff_cycle , k_effective_exp, std_k_effective 1.0178451477566641   0.9989606962707168  0.0015282940093813357
# i == 653
#  keff_cycle , k_effective_exp, std_k_effective 0.9660899177774157   0.9989095753088297  0.0015267714230576084
# i == 654
#  keff_cycle , k_effective_exp, std_k_effective 0.9860697559316698   0.9988896377011013  0.001524529192841749
# i == 655
#  keff_cycle , k_effective_exp, std_k_effective 1.130057979764327   0.9990929994717419  0.0015356882760450624
# i == 656
#  keff_cycle , k_effective_exp, std_k_effective 0.9714327843650585   0.9990501818012981  0.0015339069321694872
# i == 657
#  keff_cycle , k_effective_exp, std_k_effective 0.9717359866470627   0.9990079651163613  0.0015321160383932042
# i == 658
#  keff_cycle , k_effective_exp, std_k_effective 1.0431579086149927   0.9990760977452171  0.0015312663424726764
# i == 659
#  keff_cycle , k_effective_exp, std_k_effective 1.0112488258382226   0.9990948538747904  0.0015290201405092775
# i == 660
#  keff_cycle , k_effective_exp, std_k_effective 1.040081239854053   0.9991579098532201  0.0015279676371139882
# i == 661
#  keff_cycle , k_effective_exp, std_k_effective 0.9953461842581668   0.9991520546679742  0.0015256299589308715
# i == 662
#  keff_cycle , k_effective_exp, std_k_effective 1.0147149140709533   0.9991759240842365  0.0015234752399027815
# i == 663
#  keff_cycle , k_effective_exp, std_k_effective 0.9783660839814992   0.9991440560289491  0.0015214741935497176
# i == 664
#  keff_cycle , k_effective_exp, std_k_effective 0.9552473421088956   0.9990769356712732  0.0015206280639723394
# i == 665
#  keff_cycle , k_effective_exp, std_k_effective 0.9749308265479417   0.9990400713825353  0.0015187521842168756
# i == 666
#  keff_cycle , k_effective_exp, std_k_effective 1.0273185323666192   0.999083178792572  0.0015170478251523205
# i == 667
#  keff_cycle , k_effective_exp, std_k_effective 1.0535712162126627   0.9991661134005173  0.0015170057235592866
# i == 668
#  keff_cycle , k_effective_exp, std_k_effective 1.062960814963325   0.9992630658345032  0.001517798170901932
# i == 669
#  keff_cycle , k_effective_exp, std_k_effective 1.0299214929915388   0.9993095884857278  0.0015162071455237611
# i == 670
#  keff_cycle , k_effective_exp, std_k_effective 1.0319491912222045   0.999359042429268  0.001514715644994062
# i == 671
#  keff_cycle , k_effective_exp, std_k_effective 1.0118298348533412   0.999377908983616  0.0015125400271634804
# i == 672
#  keff_cycle , k_effective_exp, std_k_effective 0.9787489288410925   0.9993467473821923  0.0015105749452363113
# i == 673
#  keff_cycle , k_effective_exp, std_k_effective 0.9788349717398611   0.9993158095607106  0.0015086120924383828
# i == 674
#  keff_cycle , k_effective_exp, std_k_effective 0.9804242083608377   0.9992873583540844  0.0015066070372415222
# i == 675
#  keff_cycle , k_effective_exp, std_k_effective 0.974662643689012   0.9992503287079716  0.0015047954340742002
# i == 676
#  keff_cycle , k_effective_exp, std_k_effective 1.0015852671359802   0.9992538346215272  0.0015025383728601625
# i == 677
#  keff_cycle , k_effective_exp, std_k_effective 1.004414711127416   0.9992615720675629  0.0015003039525518299
# i == 678
#  keff_cycle , k_effective_exp, std_k_effective 0.9700320435612418   0.9992178152883618  0.0014986952153233952
# i == 679
#  keff_cycle , k_effective_exp, std_k_effective 0.9569352389164901   0.9991546126330973  0.001497787422727855
# i == 680
#  keff_cycle , k_effective_exp, std_k_effective 1.0173663290616113   0.9991817942994086  0.0014957972416962653
# i == 681
#  keff_cycle , k_effective_exp, std_k_effective 1.001196339143236   0.9991847966017093  0.0014935693896312061
# i == 682
#  keff_cycle , k_effective_exp, std_k_effective 1.1004282446866716   0.9993354564946929  0.0014989358857256285
# i == 683
#  keff_cycle , k_effective_exp, std_k_effective 0.9848673587752341   0.9993139585783193  0.0014968613679989355
# i == 684
#  keff_cycle , k_effective_exp, std_k_effective 0.9670633528365752   0.9992661090149042  0.0014954045903954863
# i == 685
#  keff_cycle , k_effective_exp, std_k_effective 1.0037144462953094   0.9992726991442086  0.001493202075282384
# i == 686
#  keff_cycle , k_effective_exp, std_k_effective 1.036108034493043   0.9993271892852572  0.0014919869330037908
# i == 687
#  keff_cycle , k_effective_exp, std_k_effective 0.9767831276435168   0.9992938893419164  0.00149015359936481
# i == 688
#  keff_cycle , k_effective_exp, std_k_effective 0.9962645557578914   0.9992894212982821  0.0014879608177865754
# i == 689
#  keff_cycle , k_effective_exp, std_k_effective 1.0149409515971493   0.9993124721529196  0.0014859466011741148
# i == 690
#  keff_cycle , k_effective_exp, std_k_effective 1.0130512450689273   0.9993326762307374  0.0014838973276287996
# i == 691
#  keff_cycle , k_effective_exp, std_k_effective 1.056723824893634   0.9994169510452203  0.0014841114196833096
# i == 692
#  keff_cycle , k_effective_exp, std_k_effective 0.9465483357231655   0.999339431081405  0.0014839598553441124
# i == 693
#  keff_cycle , k_effective_exp, std_k_effective 0.9852392883765293   0.9993187866557756  0.0014819293574316235
# i == 694
#  keff_cycle , k_effective_exp, std_k_effective 1.0325234015942184   0.9993673314144574  0.001480557268812724
# i == 695
#  keff_cycle , k_effective_exp, std_k_effective 0.9909222874066979   0.9993550028830592  0.0014784456951280197
# i == 696
#  keff_cycle , k_effective_exp, std_k_effective 0.942452365268506   0.9992720544317261  0.0014786174351028448
# i == 697
#  keff_cycle , k_effective_exp, std_k_effective 1.0363841275431382   0.9993260749166044  0.0014774514983857546
# i == 698
#  keff_cycle , k_effective_exp, std_k_effective 0.993699936019034   0.999317897389137  0.001475325140524724
# i == 699
#  keff_cycle , k_effective_exp, std_k_effective 0.8888568291626071   0.9991575765353975  0.001481880207652613
# i == 700
#  keff_cycle , k_effective_exp, std_k_effective 0.9647675152648499   0.9991077358668894  0.0014805701316314135
# i == 701
#  keff_cycle , k_effective_exp, std_k_effective 1.0273064629592834   0.9991485444444471  0.001478989037099423
# i == 702
#  keff_cycle , k_effective_exp, std_k_effective 0.9538486887298825   0.9990830822252064  0.0014783003361685725
# i == 703
#  keff_cycle , k_effective_exp, std_k_effective 1.0586537147919788   0.9991690427339607  0.0014786663259226036
# i == 704
#  keff_cycle , k_effective_exp, std_k_effective 0.9575236627840099   0.9991090349818713  0.0014777530285055465
# i == 705
#  keff_cycle , k_effective_exp, std_k_effective 1.0329358130868747   0.999157706605044  0.0014764277008877758
# i == 706
#  keff_cycle , k_effective_exp, std_k_effective 0.9289265386877047   0.999056799754588  0.0014777540539435462
# i == 707
#  keff_cycle , k_effective_exp, std_k_effective 1.0188082777418517   0.99908513759962  0.001475904440196882
# i == 708
#  keff_cycle , k_effective_exp, std_k_effective 1.0493481147819945   0.9991571475955834  0.0014755466194819242
# i == 709
#  keff_cycle , k_effective_exp, std_k_effective 0.9738701050795407   0.999120971569094  0.0014738782012958353
# i == 710
#  keff_cycle , k_effective_exp, std_k_effective 0.9329100208504151   0.9990263844966387  0.0014748074608799332
# i == 711
#  keff_cycle , k_effective_exp, std_k_effective 0.9850558188085923   0.999006455016342  0.0014728369384513211
# i == 712
#  keff_cycle , k_effective_exp, std_k_effective 1.0123765578891548   0.9990255007469301  0.0014708606975319023
# i == 713
#  keff_cycle , k_effective_exp, std_k_effective 1.0161231082345272   0.9990498216679651  0.001468968292616974
# i == 714
#  keff_cycle , k_effective_exp, std_k_effective 1.0530924501919323   0.9991265867653002  0.001468887476461652
# i == 715
#  keff_cycle , k_effective_exp, std_k_effective 1.0106849238593303   0.999142981569689  0.0014668940898235833
# i == 716
#  keff_cycle , k_effective_exp, std_k_effective 0.9753807335924515   0.9991093239946504  0.001465201492616133
# i == 717
#  keff_cycle , k_effective_exp, std_k_effective 1.0385993834595122   0.9991651798071891  0.0014641933812559532
# i == 718
#  keff_cycle , k_effective_exp, std_k_effective 0.9895254295958732   0.999151564340789  0.001462187241965405
# i == 719
#  keff_cycle , k_effective_exp, std_k_effective 0.9858685319186845   0.9991328294572599  0.0014602436511415731
# i == 720
#  keff_cycle , k_effective_exp, std_k_effective 1.0195836563516656   0.9991616334388013  0.0014584699786851965
# i == 721
#  keff_cycle , k_effective_exp, std_k_effective 0.9751948207863055   0.9991279248415404  0.0014568072786231246
# i == 722
#  keff_cycle , k_effective_exp, std_k_effective 1.0116278004344004   0.9991454808465866  0.0014548656909727645
# i == 723
#  keff_cycle , k_effective_exp, std_k_effective 1.0040029552528196   0.9991522935736642  0.001452839746581275
# i == 724
#  keff_cycle , k_effective_exp, std_k_effective 0.9975763064238385   0.9991500863087485  0.001450805209173286
# i == 725
#  keff_cycle , k_effective_exp, std_k_effective 1.0113367305885688   0.9991671305664825  0.0014488749460269533
# i == 726
#  keff_cycle , k_effective_exp, std_k_effective 1.0714283036666397   0.9992680539926  0.0014503655925890116
# i == 727
#  keff_cycle , k_effective_exp, std_k_effective 0.9746237520565406   0.9992336825812527  0.001448749141242536
# i == 728
#  keff_cycle , k_effective_exp, std_k_effective 1.0082416778934185   0.9992462285357265  0.0014467843755499176
# i == 729

# %%
difference = (1. - k_effective_exp[-1]) * 100000

standart_deviation = k_effective_std[-1] * 100000

print(" difference from beachmark [pcm]  " + str(difference) + "  with standart deviation [pcm]+- " + str(standart_deviation))
# Out:
#  difference from beachmark [pcm]  -107.51818544301184  with standart deviation [pcm]+- 391.4876831350764

# %%
def save_simulation_results_to_file(k_effective, file_name):
    
    f = open(file_name, "w")
    
    for i in range(0, len(k_effective)):
        f.write(" cycle k effective "+ str(k_effective[i]) + '\n')
            
    
    f.close()

# %%
file_name = "output.txt"
save_simulation_results_to_file(k_effective, file_name)
